# %% [markdown]
# ## Getting Data

# %%
import os 
import requests 

DATASET = (
    "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv",
    "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality.names"
)

def download_data(path='data', urls=DATASET):
    if not os.path.exists(path):
        os.mkdir(path) 
    
    for url in urls:
        response = requests.get(url)
        name = os.path.basename(url) 
        with open(os.path.join(path, name), 'wb') as f: 
            f.write(response.content)

download_data()

# %% [markdown]
# ## Load Data

# %%
import pandas as pd



data = pd.read_csv('data/winequality-red.csv', sep=';')

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %% [markdown]
# ## Check it out

# %%
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## Features and Targets

# %%
y = data["quality"]

# %%
y.dtype
# Out:
# dtype('int64')

# %%
y.describe()
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
X = data.iloc[:,1:-1]
X.mean()
# Out:
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor as rfr

estimator = rfr(n_estimators=7)
estimator.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=7, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_hat = estimator.predict(X)
print(y_hat)
# Out:
# [5.         5.         5.         ... 6.         4.85714286 6.        ]

# %%
import yellowbrick
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
data['poor']= np.where(data['quality']<5, 1, 0)

# %%
data['poor'].value_counts()
# Out:
# 0    1536
# 1      63
# Name: poor, dtype: int64

# %%
data['middle'] = np.where((data['quality']>4) & (data['quality']< 8) , 1, 0)

# %%
data['middle'].value_counts()
# Out:
# 1    1518
# 0      81
# Name: middle, dtype: int64

# %%
data['high'] = np.where(data['quality']>= 8 , 1, 0)

# %%
data['high'].value_counts()
# Out:
# 0    1581
# 1      18
# Name: high, dtype: int64

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (30, 30)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(data['quality'], bins = 10, range = (data['quality'].min(),data['quality'].max()))
plt.title('Qualtiy distribution')
plt.xlabel('Quality')
plt.ylabel('Count of Wines')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(data['pH'], bins = 10, range = (data['pH'].min(),data['pH'].max()))
plt.title('pH distribution')
plt.xlabel('pH')
plt.ylabel('Count of Wines')
plt.show()

# %%
g = sns.factorplot("quality", col="pH", col_wrap=4, 
                   data=data[data.quality.notnull()], kind="count", size=4, aspect=.8)

# %%
data["pH"]=data["pH"].round(0)
data["alcohol"]=data["alcohol"].round(0)

# %%
g = sns.factorplot(x="pH", 
                   y="quality", 
                   hue="alcohol", 
                   data=data,
                   size=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("Quality probability")

# %%
g = sns.factorplot(x="pH", 
                   y="quality", 
                   hue="alcohol",
               data=data,
               height=6, kind="violin", palette="muted")
g.despine(left=True)
g.set_ylabels('Quality probability')

# %%
g = sns.pairplot(data=data[['sulphates', 'pH', 'alcohol', 'density', 'residual sugar', 'citric acid','quality']], hue='quality')

# %%
sns.lmplot(x="alcohol", y="density", data=data)

# %%
sns.lmplot(x="alcohol", y="pH", data=data)

# %%
sns.lmplot(x="alcohol", y="sulphates", data=data)

# %%
sns.lmplot(x="residual sugar", y="alcohol", data=data)

# %%
from sklearn import LinearRegression
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-0f2f9163c2d0> in <module>()
# ----> 1 from sklearn import LinearRegression
#       2 from sklearn.model_selection import train_test_split
#
# ImportError: cannot import name 'LinearRegression'

# %%
y = data["quality"]
X = data.iloc[:,1:-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.metrics import r2_score
y_hat = regr.predict(X_test)
r2 = r2_score(y_test, y_hat)

# %%
train_residuals = y_train - regr.predict(X_train)
test_residuals = y_test - y_hat

# %%
from matplotlib.pyplot import scatter

# %%
scatter(y_train, train_residuals, label="Training", alpha=0.6)
scatter(y_test, test_residuals, label="Testing", alpha=0.8)
