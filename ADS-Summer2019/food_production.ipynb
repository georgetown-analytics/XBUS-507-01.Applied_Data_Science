# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Loading the data

# %%
data = pd.read_csv('data/food_production.csv', sep=',', encoding = 'ISO-8859-1')

# %%
data.head()
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# 3       Barley and products          5142    Food  1000 tonnes     33.94
# 4        Maize and products          5521    Feed  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# 1      67.71  ...   419.0   445.0   546.0   455.0   490.0   415.0   442.0
# 2      67.71  ...    58.0   236.0   262.0   263.0   230.0   379.0   315.0
# 3      67.71  ...   185.0    43.0    44.0    48.0    62.0    55.0    60.0
# 4      67.71  ...   120.0   208.0   233.0   249.0   247.0   195.0   178.0
#
#     Y2011  Y2012  Y2013
# 0  4711.0   4810   4895
# 1   476.0    425    422
# 2   203.0    367    360
# 3    72.0     78     89
# 4   191.0    200    200
#
# [5 rows x 63 columns]

# %%
#calculating total from 1961-2013
data['total'] = (data['Y1961'] + data['Y1962'] + data['Y1963'] + data['Y1964'] + data['Y1965'] + data['Y1966'] + 
    data['Y1967'] + data['Y1968'] + data['Y1969'] + data['Y1970'] + data['Y1971'] + data['Y1972'] + data['Y1973'] +
    data['Y1974'] + data['Y1975'] + data['Y1976'] + data['Y1977'] + data['Y1978'] + data['Y1979'] + data['Y1980'] + 
    data['Y1981'] + data['Y1982'] + data['Y1983'] + data['Y1984'] + data['Y1985'] + data['Y1986'] + data['Y1987'] + 
    data['Y1988'] + data['Y1989'] + data['Y1990'] + data['Y1991'] + data['Y1992'] + data['Y1993'] + data['Y1994'] + 
    data['Y1995'] + data['Y1996'] + data['Y1997'] + data['Y1998'] + data['Y1999'] + data['Y2000'] + data['Y2001'] + 
    data['Y2001'] + data['Y2002'] + data['Y2003'] + data['Y2004'] + data['Y2005'] + data['Y2006'] + data['Y2007'] + 
    data['Y2008'] + data['Y2009'] + data['Y2010'] + data['Y2011'] + data['Y2012'] + data['Y2013'] )

# %%
#we just want milk food
milkdata = data[data['Item'] == 'Milk - Excluding Butter']

# %%
milkdata = milkdata[milkdata['Element'] == 'Food']

# %%
milkdata.head(10)
# Out:
#     Area Abbreviation  Area Code                 Area  Item Code  \
# 57                AFG          2          Afghanistan       2848
# 80                AFG          2          Afghanistan       2948
# 166               ALB          3              Albania       2848
# 201               ALB          3              Albania       2948
# 291               DZA          4              Algeria       2848
# 325               DZA          4              Algeria       2948
# 400               AGO          7               Angola       2848
# 434               AGO          7               Angola       2948
# 519               ATG          8  Antigua and Barbuda       2848
# 551               ATG          8  Antigua and Barbuda       2948
#
#                         Item  Element Code Element         Unit  latitude  \
# 57   Milk - Excluding Butter          5142    Food  1000 tonnes     33.94
# 80   Milk - Excluding Butter          5142    Food  1000 tonnes     33.94
# 166  Milk - Excluding Butter          5142    Food  1000 tonnes     41.15
# 201  Milk - Excluding Butter          5142    Food  1000 tonnes     41.15
# 291  Milk - Excluding Butter          5142    Food  1000 tonnes     28.03
# 325  Milk - Excluding Butter          5142    Food  1000 tonnes     28.03
# 400  Milk - Excluding Butter          5142    Food  1000 tonnes    -11.20
# 434  Milk - Excluding Butter          5142    Food  1000 tonnes    -11.20
# 519  Milk - Excluding Butter          5142    Food  1000 tonnes     17.06
# 551  Milk - Excluding Butter          5142    Food  1000 tonnes     17.06
#
#      longitude  ...   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010   Y2011  \
# 57       67.71  ...  1590.0  1517.0  1622.0  1591.0  1629.0  1686.0  1676.0
# 80       67.71  ...  1590.0  1517.0  1622.0  1591.0  1629.0  1686.0  1676.0
# 166      20.17  ...   933.0   950.0   879.0   901.0   900.0   920.0   950.0
# 201      20.17  ...   933.0   950.0   879.0   901.0   900.0   920.0   950.0
# 291       1.66  ...  4010.0  4193.0  4268.0  4309.0  4829.0  4922.0  5702.0
# 325       1.66  ...  4010.0  4193.0  4268.0  4309.0  4829.0  4922.0  5702.0
# 400      17.87  ...   252.0   212.0   221.0   220.0   193.0   215.0   225.0
# 434      17.87  ...   252.0   212.0   221.0   220.0   193.0   215.0   225.0
# 519     -61.80  ...    10.0     9.0    11.0    11.0    11.0    11.0    12.0
# 551     -61.80  ...    10.0     9.0    11.0    11.0    11.0    11.0    12.0
#
#      Y2012  Y2013     total
# 57    1895   1901   55899.0
# 80    1895   1901   55899.0
# 166    948    964   29324.0
# 201    948    964   29324.0
# 291   5602   5549  130214.0
# 325   5602   5549  130214.0
# 400    260    264   12987.0
# 434    260    264   12987.0
# 519     11     11     443.0
# 551     11     11     443.0
#
# [10 rows x 64 columns]

# %%
#want the top 10 milk producers
by_country = milkdata.groupby(['Area'])['total'].sum().reset_index()

# %%
sorted = by_country.sort_values(by=['total'], ascending=False)

# %%
top10 = sorted.head(10)

# %%
top10
# Out:
#                          Area      total
# 165  United States of America  6855656.0
# 73                      India  5018198.0
# 61                    Germany  1875228.0
# 119                  Pakistan  1570376.0
# 56                     France  1545764.0
# 21                     Brazil  1541448.0
# 163            United Kingdom  1440568.0
# 79                      Italy  1428998.0
# 35            China, mainland  1198814.0
# 103                    Mexico   874432.0

# %%
sns.set(style="whitegrid")

ax = sns.barplot(x="Area", y="total", data=top10)

# %%
#bottom milk producers
bottom = sorted.tail(50)

# %%
#bottom milk producers
ax = sns.barplot(x="Area", y="total", data=bottom)
